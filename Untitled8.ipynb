# %%
from groq import Groq

client = Groq(api_key="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")

print("Streaming Chatbot Started! Type 'bye' to exit.\n")

while True:
    user = input("You: ")

    if user.lower() == "bye":
        print("Bot: Goodbye!")
        break

    try:
        stream = client.chat.completions.create(
            model="llama-3.1-8b-instant",
            messages=[{"role": "user", "content": user}],
            stream=True
        )

        print("Bot: ", end="", flush=True)
        full_response = ""

        for chunk in stream:
            if chunk.choices and chunk.choices[0].delta.content:
                token = chunk.choices[0].delta.content
                print(token, end="", flush=True)
                full_response += token

        print("\n")

    except Exception as e:
        print("\n[ERROR] Something went wrong:", e)
        print("Please check your API key or network.\n")
# Out:
# Streaming Chatbot Started! Type 'bye' to exit.
# You:  hi
# Bot: How can I help you today?
# You:  what is human?
# Bot: The term "human" refers to the species Homo sapiens, a member of the family Hominidae. Humans are a species of primates that belong to the order Primates, class Mammalia, and kingdom Animalia.
#
# Biological Characteristics:
#
# 1. **Bipedalism**: Humans are the only primates that walk on two legs (bipedalism). This adaptability allowed early humans to cover longer distances, free up hands for other activities, and possibly led to the development of more complex societies.
# 2. **Large brain**: The human brain is significantly larger than that of other primates, relative to body size. This allows for advanced cognitive abilities such as thinking, problem-solving, and language.
# 3. **Skull shape**: The human skull is characterized by a flat face, a prominent forehead, and a relatively small jaw.
# 4. **Diet**: Humans are omnivores, meaning we eat both plants and animals. This dietary flexibility allowed for adaptation to various environments.
#
# Behavioral Characteristics:
#
# 1. **Language**: Humans possess a complex system of language, which enables communication, social interaction, and cultural transmission.
# 2. **Social complexity**: Humans form complex societies with hierarchies, norms, and institutions, which are unique among animal species.
# 3. **Culture**: Humans have developed a vast array of cultures, including art, music, literature, and technology.
# 4. **Emotions**: Humans experience a wide range of emotions, including love, fear, anger, and happiness, which are often expressed through nonverbal cues.
#
# Physical Characteristics:
#
# 1. **Body proportions**: Humans have a relatively upright posture, with a body length that is roughly 1.5 to 2 times their height.
# 2. **Skin and hair**: Humans have a thin layer of skin that protects our body, and hair that helps regulate body temperature and provides sensory information.
#
# It is essential to note that the concept of "human" encompasses a vast array of diversity, including:
#
# 1. **Genetic diversity**: Humans come in various skin tones, eye colors, and other physical characteristics due to genetic variation.
# 2. **Cultural diversity**: Humans have developed distinct cultures, languages, and customs across the globe.
# 3. **Neurological diversity**: Humans experience the world in unique ways due to varying cognitive abilities, personality traits, and emotional responses.
#
# The definition of "human" continues to evolve as we learn more about our species, our history, and our place in the world.
# You:  ask like general questi n , i will answer pls check
# Bot: I'll ask some general questions and you can answer. I'll then provide feedback on your responses. Here's a question to start:
#
# What is the largest planet in our solar system?
# You:  jupyter
# Bot: Jupyter
# =======
#
# Jupyter is an open-source web-based interactive computing environment that supports multiple programming languages (Python, Julia, R, etc.) including notebooks, which are documents containing live code, equations, visualizations, and narrative text.
#
# Key Features
# ------------
#
# ### 1. Interactive Environment
#
# * Supports multiple programming languages including Python, Julia, R, and Haskell.
# * Allows for interactive execution of code within a notebook.
#
# ### 2. Notebooks
#
# * Rich text formatting and media support.
# * Ability to add narrative text, math equations, and visualizations.
# * Multiple cell types support: code, markdown, raw, and more.
#
# ### 3. Code Cells
#
# * Code can be executed in a specific cell or in the entire notebook.
# * Output can be displayed inline, below the cell, or in a separate output area.
#
# ### 4. File Management
#
# * Supports uploading, downloading, and creating new files.
#
# ### 5. Collaboration
#
# * Allows multiple users to collaborate in real-time.
# * Supports version control using Git.
#
# ### 6. Output Management
#
# * Different output modes for text and other content types.
# * Ability to configure output display and styling.
#
# ### 7. Extensions
#
# * Supports a wide range of community-maintained extensions.
#
# ### 8. Security
#
# * Provides secure authentication and authorization for users.
# * Supports single sign-on (SSO) integration.
#
# Installation
# -------------
#
# You can install the Jupyter notebook with pip:
#
# ```bash
# pip install notebook
# ```
#
# However, it's recommended to install it using conda for better control and integration with other packages:
#
# ```bash
# conda install notebook
# ```
#
# Basic Usage
# ------------
#
# To run a notebook, create a new empty notebook:
#
# ```bash
# jupyter notebook
# ```
#
# This will launch the Jupyter web server and open the notebook interface. You can interact with the notebook cells to execute code and display output.
#
# Some popular Jupyter notebook cell types include:
#
# * Code cells (`python`): write Python code that gets executed when you press Shift+Enter.
# * Markdown cells (`markdown`): write text in Markdown format.
# * Raw cells (`raw`): write raw cells (no syntax highlighting).
#
# Tips and Tricks
# ----------------
#
# * Use the `!` character to execute shell commands within a cell.
# * Use the `%` character to execute Python magic functions.
# * Use `%%` to execute a command-line executable within a cell.
# * Use `?` to display the docstring for an object or function.
#
# Some common use cases include:
#
# * Exploratory data analysis and visualization
# * Machine learning development and prototyping
# * Data science and scientific computing
# * Education and teaching
# You:  jupiter
# Bot: Jupiter is the largest planet in our solar system, known for its massive size, stormy atmosphere, and numerous moons. Here are some key facts about Jupiter:
#
# **Orbital Characteristics:**
#
# - Jupiter is the fifth planet from the Sun.
# - It orbits the Sun at an average distance of approximately 778.3 million kilometers (483.8 million miles).
# - Jupiter's orbital period is about 11.86 Earth years.
#
# **Physical Characteristics:**
#
# - Jupiter is the largest planet in our solar system, with a diameter of approximately 142,984 kilometers (88,846 miles).
# - Its mass is about 318 times that of Earth.
# - Jupiter is a gas giant, composed primarily of hydrogen and helium.
#
# **Atmosphere:**
#
# - Jupiter's atmosphere is known for its distinctive banded pattern, created by strong winds and storm systems.
# - The most famous feature in Jupiter's atmosphere is the Great Red Spot, a persistent anticyclonic storm that has been raging for centuries.
# - Jupiter's atmosphere is also home to numerous cloud layers, including ammonia, water, and sulfur clouds.
#
# **Moons:**
#
# - Jupiter has a total of 92 confirmed moons.
# - Four of the largest moons - Io, Europa, Ganymede, and Callisto - are known as the Galilean moons, as they were first discovered by Galileo Galilei in 1610.
# - Each of these large moons has its own unique features, including volcanoes, lakes of liquid water, and potential for habitability.
#
# **Rings:**
#
# - Jupiter has a faint ring system, composed of dust and debris ejected by meteoroid impacts on its moons.
# - The ring system is relatively faint and consists of three main components: the halo ring, the main ring, and the Amalthea ring.
#
# **Unique Features:**
#
# - Jupiter is a gas giant, meaning it does not have a solid surface like Earth.
# - Jupiter has an extremely strong magnetic field, which traps charged particles from the solar wind and creates spectacular aurora displays.
# - Jupiter is thought to have formed just 1-2 million years after the formation of the solar system, making it one of the oldest planets in our solar system.
#
# These are just a few of the many fascinating facts about Jupiter. The planet continues to capture the imagination of scientists and the general public alike with its sheer size, stormy atmosphere, and intricate moon system.
# You:  ask an ther questi f r me?
# Bot: What is the only bird species in the world that can fly backwards?
